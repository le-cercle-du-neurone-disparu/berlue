# %% [markdown]
# # 1) Exploration des données

# %%
# from sklearn.compose import ColumnTransformer, make_column_transformer
# from sklearn.pipeline import make_pipeline
# from sklearn.preprocessing import FunctionTransformer, OneHotEncoder

# from sklearn import set_config; set_config(display='diagram')

# %% [markdown]
# ## 1.1) Chargement des données

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 1.1.1) Compression des données

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 1.2) Nettoyage des données

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 1.3) Visualisation des données

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 1.4) Score de référence - Intuitions préliminaires

# %%
# YOUR CODE HERE

# %% [markdown]
# # 2) Split Train/Val/Test

# %%
# YOUR CODE HERE

# %% [markdown]
# # 3) Pipeline de prétraitement

# %%
# YOUR CODE HERE

# %% [markdown]
# # 4) Modèle

# %% [markdown]
# ## 4.1) Architecture

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 4.2) Évaluation de la performance

# %%
# YOUR CODE HERE
